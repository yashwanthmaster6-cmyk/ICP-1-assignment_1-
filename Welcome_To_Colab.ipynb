# %% [markdown]
# <a href="https://colab.research.google.com/github/yashwanthmaster6-cmyk/ICP-1-assignment_1-/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input string from user
user_input = input("Enter a string: ")

# Convert string to list of characters
char_list = list(user_input)

# Delete at least two characters (remove first and last characters)
if len(char_list) >= 2:
    del char_list[0]
    del char_list[-1]

# Reverse the list
char_list.reverse()

# Convert back to string and print
result = "".join(char_list)
print(result)
# Out:
# Enter a string: python
# ohty

# %%
# Take two numbers from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Arithmetic operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2

# Handle division safely
if num2 != 0:
    division = num1 / num2
else:
    division = "Undefined (division by zero)"

# Print results
print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
# Out:
# Enter first number: 2
# Enter second number: 2
# Addition: 4.0
# Subtraction: 0.0
# Multiplication: 4.0
# Division: 1.0

# %%
# Input class score
score = float(input("Enter your class score: "))

# Determine grade
if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"

elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

# Print grade
print("Your grade is:", grade)
# Out:
# Enter your class score: 90
# Your grade is: A
